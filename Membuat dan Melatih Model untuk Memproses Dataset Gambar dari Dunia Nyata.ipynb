# %%
# !wget --no-check-certificate \
https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
-O /tmp/Chessman-image-dataset.zip
# Out:
# --2021-09-13 09:52:29--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2021-09-13 09:52:29--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   132MB/s    in 0.4s
#
# 2021-09-13 09:52:30 (132 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import zipfile, os

# %%
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['King', 'Queen', 'Bishop', 'Pawn', 'Knight', 'Rook']

# %%
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
 
train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('cats') and 1 for the other ('dogs')
    tf.keras.layers.Dense(6, activation='softmax')  
])

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.9):
      self.model.stop_training = True
callbacks = myCallback()

# %%
history = model.fit(train_generator, 
                    validation_data=validation_generator, 
                    epochs=50, 
                    verbose=2
                    )
# Out:
# Epoch 1/50
# 63/63 - 36s - loss: 1.7850 - accuracy: 0.1623 - val_loss: 1.7799 - val_accuracy: 0.2308
# Epoch 2/50
# 63/63 - 35s - loss: 1.7756 - accuracy: 0.1784 - val_loss: 1.7824 - val_accuracy: 0.1731
# Epoch 3/50
# 63/63 - 35s - loss: 1.7688 - accuracy: 0.2084 - val_loss: 1.7506 - val_accuracy: 0.1923
# Epoch 4/50
# 63/63 - 35s - loss: 1.7274 - accuracy: 0.2505 - val_loss: 1.7479 - val_accuracy: 0.2692
# Epoch 5/50
# 63/63 - 36s - loss: 1.6867 - accuracy: 0.2786 - val_loss: 1.7576 - val_accuracy: 0.2308
# Epoch 6/50
# 63/63 - 35s - loss: 1.7207 - accuracy: 0.2665 - val_loss: 1.7545 - val_accuracy: 0.2308
# Epoch 7/50
# 63/63 - 36s - loss: 1.6483 - accuracy: 0.3246 - val_loss: 1.7142 - val_accuracy: 0.3077
# Epoch 8/50
# 63/63 - 35s - loss: 1.6234 - accuracy: 0.3226 - val_loss: 1.6854 - val_accuracy: 0.2885
# Epoch 9/50
# 63/63 - 36s - loss: 1.5564 - accuracy: 0.3507 - val_loss: 1.7182 - val_accuracy: 0.2308
# Epoch 10/50
# 63/63 - 35s - loss: 1.5288 - accuracy: 0.3988 - val_loss: 1.5871 - val_accuracy: 0.3654
# Epoch 11/50
# 63/63 - 35s - loss: 1.4677 - accuracy: 0.4248 - val_loss: 1.5519 - val_accuracy: 0.3077
# Epoch 12/50
# 63/63 - 36s - loss: 1.4023 - accuracy: 0.4269 - val_loss: 1.5668 - val_accuracy: 0.3654
# Epoch 13/50
# 63/63 - 36s - loss: 1.4236 - accuracy: 0.4349 - val_loss: 1.5434 - val_accuracy: 0.2885
# Epoch 14/50
# 63/63 - 35s - loss: 1.3097 - accuracy: 0.4669 - val_loss: 1.5646 - val_accuracy: 0.2885
# Epoch 15/50
# 63/63 - 35s - loss: 1.3105 - accuracy: 0.4910 - val_loss: 1.6069 - val_accuracy: 0.4038
# Epoch 16/50
# 63/63 - 35s - loss: 1.3384 - accuracy: 0.4609 - val_loss: 1.6376 - val_accuracy: 0.3846
# Epoch 17/50
# 63/63 - 35s - loss: 1.2790 - accuracy: 0.5130 - val_loss: 1.4036 - val_accuracy: 0.4038
# Epoch 18/50
# 63/63 - 35s - loss: 1.2212 - accuracy: 0.5371 - val_loss: 1.4332 - val_accuracy: 0.3462
# Epoch 19/50
# 63/63 - 35s - loss: 1.1685 - accuracy: 0.5471 - val_loss: 1.4364 - val_accuracy: 0.4808
# Epoch 20/50
# 63/63 - 35s - loss: 1.1708 - accuracy: 0.5531 - val_loss: 1.5096 - val_accuracy: 0.3846
# Epoch 21/50
# 63/63 - 35s - loss: 1.0985 - accuracy: 0.5772 - val_loss: 1.4782 - val_accuracy: 0.5000
# Epoch 22/50
# 63/63 - 35s - loss: 1.1004 - accuracy: 0.5892 - val_loss: 1.5945 - val_accuracy: 0.4231
# Epoch 23/50
# 63/63 - 36s - loss: 1.0437 - accuracy: 0.6052 - val_loss: 1.5550 - val_accuracy: 0.4231
# Epoch 24/50
# 63/63 - 36s - loss: 0.9366 - accuracy: 0.6253 - val_loss: 1.4034 - val_accuracy: 0.4615
# Epoch 25/50
# 63/63 - 35s - loss: 1.0029 - accuracy: 0.6192 - val_loss: 1.5107 - val_accuracy: 0.5000
# Epoch 26/50
# 63/63 - 35s - loss: 0.9060 - accuracy: 0.6373 - val_loss: 1.5595 - val_accuracy: 0.4038
# Epoch 27/50
# 63/63 - 34s - loss: 0.8893 - accuracy: 0.6593 - val_loss: 1.5137 - val_accuracy: 0.5000
# Epoch 28/50
# 63/63 - 35s - loss: 0.9057 - accuracy: 0.6613 - val_loss: 1.6896 - val_accuracy: 0.4038
# Epoch 29/50
# 63/63 - 35s - loss: 0.8818 - accuracy: 0.6613 - val_loss: 1.3122 - val_accuracy: 0.4231
# Epoch 30/50
# 63/63 - 35s - loss: 0.8309 - accuracy: 0.7074 - val_loss: 1.4199 - val_accuracy: 0.4231
# Epoch 31/50
# 63/63 - 35s - loss: 0.7922 - accuracy: 0.6994 - val_loss: 1.4592 - val_accuracy: 0.4423
# Epoch 32/50
# 63/63 - 35s - loss: 0.7343 - accuracy: 0.7375 - val_loss: 1.4922 - val_accuracy: 0.4038
# Epoch 33/50
# 63/63 - 35s - loss: 0.7183 - accuracy: 0.7655 - val_loss: 1.6242 - val_accuracy: 0.4038
# Epoch 34/50
# 63/63 - 35s - loss: 0.6843 - accuracy: 0.7555 - val_loss: 1.6341 - val_accuracy: 0.5192
# Epoch 35/50
# 63/63 - 35s - loss: 0.6610 - accuracy: 0.7515 - val_loss: 1.6161 - val_accuracy: 0.4231
# Epoch 36/50
# 63/63 - 36s - loss: 0.6459 - accuracy: 0.7916 - val_loss: 1.4265 - val_accuracy: 0.5192
# Epoch 37/50
# 63/63 - 35s - loss: 0.5251 - accuracy: 0.7996 - val_loss: 1.6560 - val_accuracy: 0.5000
# Epoch 38/50
# 63/63 - 36s - loss: 0.5636 - accuracy: 0.7996 - val_loss: 1.5333 - val_accuracy: 0.4808
# Epoch 39/50
# 63/63 - 35s - loss: 0.5818 - accuracy: 0.8056 - val_loss: 1.4587 - val_accuracy: 0.4038
# Epoch 40/50
# 63/63 - 35s - loss: 0.5261 - accuracy: 0.7976 - val_loss: 1.4630 - val_accuracy: 0.5385
# Epoch 41/50
# 63/63 - 35s - loss: 0.5196 - accuracy: 0.7976 - val_loss: 2.1157 - val_accuracy: 0.4038
# Epoch 42/50
# 63/63 - 35s - loss: 0.4563 - accuracy: 0.8557 - val_loss: 1.9013 - val_accuracy: 0.4038
# Epoch 43/50
# 63/63 - 35s - loss: 0.5768 - accuracy: 0.7936 - val_loss: 1.4959 - val_accuracy: 0.4615
# Epoch 44/50
# 63/63 - 35s - loss: 0.5324 - accuracy: 0.8016 - val_loss: 1.4774 - val_accuracy: 0.5000
# Epoch 45/50
# 63/63 - 35s - loss: 0.4932 - accuracy: 0.8236 - val_loss: 1.7308 - val_accuracy: 0.4038
# Epoch 46/50
# 63/63 - 36s - loss: 0.4869 - accuracy: 0.8176 - val_loss: 1.4418 - val_accuracy: 0.4615
# Epoch 47/50
# 63/63 - 36s - loss: 0.5199 - accuracy: 0.8357 - val_loss: 1.6018 - val_accuracy: 0.4615
# Epoch 48/50
# 63/63 - 35s - loss: 0.4655 - accuracy: 0.8617 - val_loss: 1.4710 - val_accuracy: 0.5000
# Epoch 49/50
# 63/63 - 35s - loss: 0.4135 - accuracy: 0.8577 - val_loss: 1.4584 - val_accuracy: 0.5577
# Epoch 50/50
# 63/63 - 36s - loss: 0.3934 - accuracy: 0.8477 - val_loss: 1.8825 - val_accuracy: 0.3654

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
