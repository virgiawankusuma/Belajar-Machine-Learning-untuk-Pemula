# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(num_words=15,oov_token='-')

# %%
teks = ['Saya suka programming',
        'Programming sangat menyenangkan!',
        'Machine Learning berbeda dengan pemrograman konvensional']

# %%
tokenizer.fit_on_texts(teks)

# %%
sequences = tokenizer.texts_to_sequences(teks)

# %%
print(tokenizer.word_index)
# Out:
# {'-': 1, 'programming': 2, 'saya': 3, 'suka': 4, 'sangat': 5, 'menyenangkan': 6, 'machine': 7, 'learning': 8, 'berbeda': 9, 'dengan': 10, 'pemrograman': 11, 'konvensional': 12}

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
sequences_samapanjang = pad_sequences(sequences, padding='post',maxlen=5, truncating='post')

# %%
print(sequences_samapanjang)
# Out:
# [[ 3  4  2  0  0]
#  [ 2  5  6  0  0]
#  [ 7  8  9 10 11]]

# %% [markdown]
# #embedding

# %%
import tensorflow as tf
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(jumlah_kata, dimensi_embedding, panjang_input),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e51a6c2a3326> in <module>()
#       1 import tensorflow as tf
#       2 model = tf.keras.Sequential([
# ----> 3     tf.keras.layers.Embedding(jumlah_kata, dimensi_embedding, panjang_input),
#       4     tf.keras.layers.Flatten(),
#       5     tf.keras.layers.Dense(24, activation='relu'),
#
# NameError: name 'jumlah_kata' is not defined

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(padded_latih, label_latih, 
          epochs=num_epochs, 
          validation_data=(padded_test, label_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-188a4168734e> in <module>()
# ----> 1 model.fit(padded_latih, label_latih,
#       2           epochs=num_epochs,
#       3           validation_data=(padded_test, label_test))
#
# NameError: name 'model' is not defined
