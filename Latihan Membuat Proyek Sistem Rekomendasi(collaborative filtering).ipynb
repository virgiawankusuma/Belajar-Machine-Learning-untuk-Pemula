# %%
# Import library
import pandas as pd
import numpy as np 
from zipfile import ZipFile
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00232/RCdata.zip
# Out:
# --2021-10-10 02:03:43--  https://archive.ics.uci.edu/ml/machine-learning-databases/00232/RCdata.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39674 (39K) [application/x-httpd-php]
# Saving to: ‘RCdata.zip’
#
# RCdata.zip          100%[===================>]  38.74K  --.-KB/s    in 0.1s
#
# 2021-10-10 02:03:44 (259 KB/s) - ‘RCdata.zip’ saved [39674/39674]

# %%
# !unzip 'RCdata.zip'
# Out:
# Archive:  RCdata.zip
#   inflating: chefmozaccepts.csv
#   inflating: chefmozcuisine.csv
#   inflating: chefmozhours4.csv
#   inflating: chefmozparking.csv
#   inflating: geoplaces2.csv
#   inflating: rating_final.csv
#   inflating: README
#   inflating: usercuisine.csv
#   inflating: userpayment.csv
#   inflating: userprofile.csv

# %%
df = pd.read_csv('rating_final.csv')
df
# Out:
#      userID  placeID  rating  food_rating  service_rating
# 0     U1077   135085       2            2               2
# 1     U1077   135038       2            2               1
# 2     U1077   132825       2            2               2
# 3     U1077   135060       1            2               2
# 4     U1068   135104       1            1               2
# ...     ...      ...     ...          ...             ...
# 1156  U1043   132630       1            1               1
# 1157  U1011   132715       1            1               0
# 1158  U1068   132733       1            1               0
# 1159  U1068   132594       1            1               1
# 1160  U1068   132660       0            0               0
#
# [1161 rows x 5 columns]

# %%
# Mengubah userID menjadi list tanpa nilai yang sama
user_ids = df['userID'].unique().tolist()
print('list userID: ', user_ids)
 
# Melakukan encoding userID
user_to_user_encoded = {x: i for i, x in enumerate(user_ids)}
print('encoded userID : ', user_to_user_encoded)
 
# Melakukan proses encoding angka ke ke userID
user_encoded_to_user = {i: x for i, x in enumerate(user_ids)}
print('encoded angka ke userID: ', user_encoded_to_user)
# Out:
# list userID:  ['U1077', 'U1068', 'U1067', 'U1103', 'U1107', 'U1044', 'U1070', 'U1031', 'U1082', 'U1023', 'U1060', 'U1015', 'U1123', 'U1021', 'U1026', 'U1083', 'U1108', 'U1012', 'U1093', 'U1030', 'U1066', 'U1127', 'U1017', 'U1100', 'U1133', 'U1118', 'U1072', 'U1080', 'U1063', 'U1074', 'U1117', 'U1020', 'U1051', 'U1055', 'U1053', 'U1035', 'U1064', 'U1081', 'U1001', 'U1014', 'U1088', 'U1056', 'U1134', 'U1106', 'U1126', 'U1124', 'U1018', 'U1125', 'U1119', 'U1076', 'U1022', 'U1094', 'U1116', 'U1105', 'U1075', 'U1007', 'U1115', 'U1024', 'U1132', 'U1005', 'U1120', 'U1004', 'U1037', 'U1052', 'U1036', 'U1038', 'U1071', 'U1114', 'U1084', 'U1049', 'U1019', 'U1069', 'U1113', 'U1104', 'U1079', 'U1045', 'U1009', 'U1016', 'U1047', 'U1095', 'U1034', 'U1078', 'U1099', 'U1008', 'U1040', 'U1121', 'U1110', 'U1042', 'U1013', 'U1054', 'U1111', 'U1128', 'U1062', 'U1101', 'U1135', 'U1032', 'U1048', 'U1092', 'U1085', 'U1109', 'U1102', 'U1098', 'U1046', 'U1122', 'U1138', 'U1033', 'U1089', 'U1003', 'U1091', 'U1027', 'U1029', 'U1086', 'U1137', 'U1090', 'U1061', 'U1041', 'U1059', 'U1112', 'U1057', 'U1025', 'U1097', 'U1006', 'U1131', 'U1073', 'U1058', 'U1002', 'U1096', 'U1136', 'U1010', 'U1028', 'U1050', 'U1129', 'U1087', 'U1065', 'U1039', 'U1130', 'U1043', 'U1011']
# encoded userID :  {'U1077': 0, 'U1068': 1, 'U1067': 2, 'U1103': 3, 'U1107': 4, 'U1044': 5, 'U1070': 6, 'U1031': 7, 'U1082': 8, 'U1023': 9, 'U1060': 10, 'U1015': 11, 'U1123': 12, 'U1021': 13, 'U1026': 14, 'U1083': 15, 'U1108': 16, 'U1012': 17, 'U1093': 18, 'U1030': 19, 'U1066': 20, 'U1127': 21, 'U1017': 22, 'U1100': 23, 'U1133': 24, 'U1118': 25, 'U1072': 26, 'U1080': 27, 'U1063': 28, 'U1074': 29, 'U1117': 30, 'U1020': 31, 'U1051': 32, 'U1055': 33, 'U1053': 34, 'U1035': 35, 'U1064': 36, 'U1081': 37, 'U1001': 38, 'U1014': 39, 'U1088': 40, 'U1056': 41, 'U1134': 42, 'U1106': 43, 'U1126': 44, 'U1124': 45, 'U1018': 46, 'U1125': 47, 'U1119': 48, 'U1076': 49, 'U1022': 50, 'U1094': 51, 'U1116': 52, 'U1105': 53, 'U1075': 54, 'U1007': 55, 'U1115': 56, 'U1024': 57, 'U1132': 58, 'U1005': 59, 'U1120': 60, 'U1004': 61, 'U1037': 62, 'U1052': 63, 'U1036': 64, 'U1038': 65, 'U1071': 66, 'U1114': 67, 'U1084': 68, 'U1049': 69, 'U1019': 70, 'U1069': 71, 'U1113': 72, 'U1104': 73, 'U1079': 74, 'U1045': 75, 'U1009': 76, 'U1016': 77, 'U1047': 78, 'U1095': 79, 'U1034': 80, 'U1078': 81, 'U1099': 82, 'U1008': 83, 'U1040': 84, 'U1121': 85, 'U1110': 86, 'U1042': 87, 'U1013': 88, 'U1054': 89, 'U1111': 90, 'U1128': 91, 'U1062': 92, 'U1101': 93, 'U1135': 94, 'U1032': 95, 'U1048': 96, 'U1092': 97, 'U1085': 98, 'U1109': 99, 'U1102': 100, 'U1098': 101, 'U1046': 102, 'U1122': 103, 'U1138': 104, 'U1033': 105, 'U1089': 106, 'U1003': 107, 'U1091': 108, 'U1027': 109, 'U1029': 110, 'U1086': 111, 'U1137': 112, 'U1090': 113, 'U1061': 114, 'U1041': 115, 'U1059': 116, 'U1112': 117, 'U1057': 118, 'U1025': 119, 'U1097': 120, 'U1006': 121, 'U1131': 122, 'U1073': 123, 'U1058': 124, 'U1002': 125, 'U1096': 126, 'U1136': 127, 'U1010': 128, 'U1028': 129, 'U1050': 130, 'U1129': 131, 'U1087': 132, 'U1065': 133, 'U1039': 134, 'U1130': 135, 'U1043': 136, 'U1011': 137}
# encoded angka ke userID:  {0: 'U1077', 1: 'U1068', 2: 'U1067', 3: 'U1103', 4: 'U1107', 5: 'U1044', 6: 'U1070', 7: 'U1031', 8: 'U1082', 9: 'U1023', 10: 'U1060', 11: 'U1015', 12: 'U1123', 13: 'U1021', 14: 'U1026', 15: 'U1083', 16: 'U1108', 17: 'U1012', 18: 'U1093', 19: 'U1030', 20: 'U1066', 21: 'U1127', 22: 'U1017', 23: 'U1100', 24: 'U1133', 25: 'U1118', 26: 'U1072', 27: 'U1080', 28: 'U1063', 29: 'U1074', 30: 'U1117', 31: 'U1020', 32: 'U1051', 33: 'U1055', 34: 'U1053', 35: 'U1035', 36: 'U1064', 37: 'U1081', 38: 'U1001', 39: 'U1014', 40: 'U1088', 41: 'U1056', 42: 'U1134', 43: 'U1106', 44: 'U1126', 45: 'U1124', 46: 'U1018', 47: 'U1125', 48: 'U1119', 49: 'U1076', 50: 'U1022', 51: 'U1094', 52: 'U1116', 53: 'U1105', 54: 'U1075', 55: 'U1007', 56: 'U1115', 57: 'U1024', 58: 'U1132', 59: 'U1005', 60: 'U1120', 61: 'U1004', 62: 'U1037', 63: 'U1052', 64: 'U1036', 65: 'U1038', 66: 'U1071', 67: 'U1114', 68: 'U1084', 69: 'U1049', 70: 'U1019', 71: 'U1069', 72: 'U1113', 73: 'U1104', 74: 'U1079', 75: 'U1045', 76: 'U1009', 77: 'U1016', 78: 'U1047', 79: 'U1095', 80: 'U1034', 81: 'U1078', 82: 'U1099', 83: 'U1008', 84: 'U1040', 85: 'U1121', 86: 'U1110', 87: 'U1042', 88: 'U1013', 89: 'U1054', 90: 'U1111', 91: 'U1128', 92: 'U1062', 93: 'U1101', 94: 'U1135', 95: 'U1032', 96: 'U1048', 97: 'U1092', 98: 'U1085', 99: 'U1109', 100: 'U1102', 101: 'U1098', 102: 'U1046', 103: 'U1122', 104: 'U1138', 105: 'U1033', 106: 'U1089', 107: 'U1003', 108: 'U1091', 109: 'U1027', 110: 'U1029', 111: 'U1086', 112: 'U1137', 113: 'U1090', 114: 'U1061', 115: 'U1041', 116: 'U1059', 117: 'U1112', 118: 'U1057', 119: 'U1025', 120: 'U1097', 121: 'U1006', 122: 'U1131', 123: 'U1073', 124: 'U1058', 125: 'U1002', 126: 'U1096', 127: 'U1136', 128: 'U1010', 129: 'U1028', 130: 'U1050', 131: 'U1129', 132: 'U1087', 133: 'U1065', 134: 'U1039', 135: 'U1130', 136: 'U1043', 137: 'U1011'}

# %%
# Mengubah placeID menjadi list tanpa nilai yang sama
resto_ids = df['placeID'].unique().tolist()
 
# Melakukan proses encoding placeID
resto_to_resto_encoded = {x: i for i, x in enumerate(resto_ids)}
 
# Melakukan proses encoding angka ke placeID
resto_encoded_to_resto = {i: x for i, x in enumerate(resto_ids)}
 
# Selanjutnya, petakan userID dan placeID ke dataframe yang berkaitan.
 
# Mapping userID ke dataframe user
df['user'] = df['userID'].map(user_to_user_encoded)
 
# Mapping placeID ke dataframe resto
df['resto'] = df['placeID'].map(resto_to_resto_encoded)

# %%
# Mendapatkan jumlah user
num_users = len(user_to_user_encoded)
print(num_users)
 
# Mendapatkan jumlah resto
num_resto = len(resto_encoded_to_resto)
print(num_resto)
 
# Mengubah rating menjadi nilai float
df['rating'] = df['rating'].values.astype(np.float32)
 
# Nilai minimum rating
min_rating = min(df['rating'])
 
# Nilai maksimal rating
max_rating = max(df['rating'])
 
print('Number of User: {}, Number of Resto: {}, Min Rating: {}, Max Rating: {}'.format(
    num_users, num_resto, min_rating, max_rating
))
# Out:
# 138
# 130
# Number of User: 138, Number of Resto: 130, Min Rating: 0.0, Max Rating: 2.0

# %%
# Mengacak dataset
df = df.sample(frac=1, random_state=42)
df
# Out:
#      userID  placeID  rating  food_rating  service_rating  user  resto
# 538   U1052   132870     1.0            1               1    63    116
# 673   U1015   132869     2.0            2               2    11    115
# 578   U1047   132875     0.0            0               0    78    117
# 242   U1056   135076     2.0            2               2    41     71
# 1063  U1002   135106     1.0            1               1   125     64
# ...     ...      ...     ...          ...             ...   ...    ...
# 1044  U1073   135065     0.0            0               0   123     94
# 1095  U1058   135062     2.0            2               2   124     76
# 1130  U1087   132660     1.0            1               0   132     14
# 860   U1029   132937     1.0            1               1   110    126
# 1126  U1028   132663     0.0            0               0   129      6
#
# [1161 rows x 7 columns]

# %%
# Membuat variabel x untuk mencocokkan data user dan resto menjadi satu value
x = df[['user', 'resto']].values
 
# Membuat variabel y untuk membuat rating dari hasil 
y = df['rating'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values
 
# Membagi menjadi 80% data train dan 20% data validasi
train_indices = int(0.8 * df.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:]
)
 
print(x, y)
# Out:
# [[ 63 116]
#  [ 11 115]
#  [ 78 117]
#  ...
#  [132  14]
#  [110 126]
#  [129   6]] [0.5 1.  0.  ... 0.5 0.5 0. ]

# %%
class RecommenderNet(tf.keras.Model):
 
  # Insialisasi fungsi
  def __init__(self, num_users, num_resto, embedding_size, **kwargs):
    super(RecommenderNet, self).__init__(**kwargs)
    self.num_users = num_users
    self.num_resto = num_resto
    self.embedding_size = embedding_size
    self.user_embedding = layers.Embedding( # layer embedding user
        num_users,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.user_bias = layers.Embedding(num_users, 1) # layer embedding user bias
    self.resto_embedding = layers.Embedding( # layer embeddings resto
        num_resto,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.resto_bias = layers.Embedding(num_resto, 1) # layer embedding resto bias
 
  def call(self, inputs):
    user_vector = self.user_embedding(inputs[:,0]) # memanggil layer embedding 1
    user_bias = self.user_bias(inputs[:, 0]) # memanggil layer embedding 2
    resto_vector = self.resto_embedding(inputs[:, 1]) # memanggil layer embedding 3
    resto_bias = self.resto_bias(inputs[:, 1]) # memanggil layer embedding 4
 
    dot_user_resto = tf.tensordot(user_vector, resto_vector, 2) 
 
    x = dot_user_resto + user_bias + resto_bias
    
    return tf.nn.sigmoid(x) # activation sigmoid

# %%
model = RecommenderNet(num_users, num_resto, 50) # inisialisasi model
 
# model compile
model.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.001),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

# %%
# Memulai training
 
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = 8,
    epochs = 100,
    validation_data = (x_val, y_val)
)
# Out:
# Epoch 1/100
# 116/116 [==============================] - 1s 3ms/step - loss: 0.7010 - root_mean_squared_error: 0.4032 - val_loss: 0.6976 - val_root_mean_squared_error: 0.4038
# Epoch 2/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.6794 - root_mean_squared_error: 0.3898 - val_loss: 0.6925 - val_root_mean_squared_error: 0.4006
# Epoch 3/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.6622 - root_mean_squared_error: 0.3790 - val_loss: 0.6876 - val_root_mean_squared_error: 0.3977
# Epoch 4/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.6474 - root_mean_squared_error: 0.3697 - val_loss: 0.6846 - val_root_mean_squared_error: 0.3958
# Epoch 5/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.6441 - root_mean_squared_error: 0.3676 - val_loss: 0.6805 - val_root_mean_squared_error: 0.3933
# Epoch 6/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.6300 - root_mean_squared_error: 0.3583 - val_loss: 0.6773 - val_root_mean_squared_error: 0.3913
# Epoch 7/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.6250 - root_mean_squared_error: 0.3551 - val_loss: 0.6721 - val_root_mean_squared_error: 0.3880
# Epoch 8/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.6186 - root_mean_squared_error: 0.3509 - val_loss: 0.6690 - val_root_mean_squared_error: 0.3861
# Epoch 9/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.6088 - root_mean_squared_error: 0.3447 - val_loss: 0.6673 - val_root_mean_squared_error: 0.3850
# Epoch 10/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.6102 - root_mean_squared_error: 0.3454 - val_loss: 0.6637 - val_root_mean_squared_error: 0.3827
# Epoch 11/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5982 - root_mean_squared_error: 0.3371 - val_loss: 0.6615 - val_root_mean_squared_error: 0.3814
# Epoch 12/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5911 - root_mean_squared_error: 0.3326 - val_loss: 0.6563 - val_root_mean_squared_error: 0.3780
# Epoch 13/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5904 - root_mean_squared_error: 0.3323 - val_loss: 0.6531 - val_root_mean_squared_error: 0.3760
# Epoch 14/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5825 - root_mean_squared_error: 0.3271 - val_loss: 0.6516 - val_root_mean_squared_error: 0.3751
# Epoch 15/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5821 - root_mean_squared_error: 0.3266 - val_loss: 0.6502 - val_root_mean_squared_error: 0.3742
# Epoch 16/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5707 - root_mean_squared_error: 0.3185 - val_loss: 0.6490 - val_root_mean_squared_error: 0.3735
# Epoch 17/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5683 - root_mean_squared_error: 0.3171 - val_loss: 0.6481 - val_root_mean_squared_error: 0.3729
# Epoch 18/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5651 - root_mean_squared_error: 0.3150 - val_loss: 0.6450 - val_root_mean_squared_error: 0.3709
# Epoch 19/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5621 - root_mean_squared_error: 0.3123 - val_loss: 0.6411 - val_root_mean_squared_error: 0.3684
# Epoch 20/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5541 - root_mean_squared_error: 0.3072 - val_loss: 0.6392 - val_root_mean_squared_error: 0.3672
# Epoch 21/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5521 - root_mean_squared_error: 0.3059 - val_loss: 0.6379 - val_root_mean_squared_error: 0.3664
# Epoch 22/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5570 - root_mean_squared_error: 0.3092 - val_loss: 0.6366 - val_root_mean_squared_error: 0.3656
# Epoch 23/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5376 - root_mean_squared_error: 0.2958 - val_loss: 0.6356 - val_root_mean_squared_error: 0.3650
# Epoch 24/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5459 - root_mean_squared_error: 0.3017 - val_loss: 0.6345 - val_root_mean_squared_error: 0.3642
# Epoch 25/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5411 - root_mean_squared_error: 0.2982 - val_loss: 0.6326 - val_root_mean_squared_error: 0.3631
# Epoch 26/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5405 - root_mean_squared_error: 0.2982 - val_loss: 0.6300 - val_root_mean_squared_error: 0.3613
# Epoch 27/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5358 - root_mean_squared_error: 0.2947 - val_loss: 0.6285 - val_root_mean_squared_error: 0.3604
# Epoch 28/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5271 - root_mean_squared_error: 0.2893 - val_loss: 0.6277 - val_root_mean_squared_error: 0.3599
# Epoch 29/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5314 - root_mean_squared_error: 0.2911 - val_loss: 0.6268 - val_root_mean_squared_error: 0.3593
# Epoch 30/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5275 - root_mean_squared_error: 0.2889 - val_loss: 0.6260 - val_root_mean_squared_error: 0.3588
# Epoch 31/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5247 - root_mean_squared_error: 0.2872 - val_loss: 0.6255 - val_root_mean_squared_error: 0.3586
# Epoch 32/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5268 - root_mean_squared_error: 0.2879 - val_loss: 0.6241 - val_root_mean_squared_error: 0.3577
# Epoch 33/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5313 - root_mean_squared_error: 0.2906 - val_loss: 0.6245 - val_root_mean_squared_error: 0.3580
# Epoch 34/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5183 - root_mean_squared_error: 0.2822 - val_loss: 0.6234 - val_root_mean_squared_error: 0.3573
# Epoch 35/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5208 - root_mean_squared_error: 0.2843 - val_loss: 0.6207 - val_root_mean_squared_error: 0.3556
# Epoch 36/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5217 - root_mean_squared_error: 0.2841 - val_loss: 0.6201 - val_root_mean_squared_error: 0.3552
# Epoch 37/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5145 - root_mean_squared_error: 0.2783 - val_loss: 0.6185 - val_root_mean_squared_error: 0.3542
# Epoch 38/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5153 - root_mean_squared_error: 0.2792 - val_loss: 0.6172 - val_root_mean_squared_error: 0.3534
# Epoch 39/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5147 - root_mean_squared_error: 0.2791 - val_loss: 0.6161 - val_root_mean_squared_error: 0.3528
# Epoch 40/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5128 - root_mean_squared_error: 0.2779 - val_loss: 0.6158 - val_root_mean_squared_error: 0.3526
# Epoch 41/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5096 - root_mean_squared_error: 0.2752 - val_loss: 0.6146 - val_root_mean_squared_error: 0.3518
# Epoch 42/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5058 - root_mean_squared_error: 0.2725 - val_loss: 0.6135 - val_root_mean_squared_error: 0.3511
# Epoch 43/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5023 - root_mean_squared_error: 0.2713 - val_loss: 0.6127 - val_root_mean_squared_error: 0.3506
# Epoch 44/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4988 - root_mean_squared_error: 0.2685 - val_loss: 0.6119 - val_root_mean_squared_error: 0.3502
# Epoch 45/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5015 - root_mean_squared_error: 0.2713 - val_loss: 0.6107 - val_root_mean_squared_error: 0.3495
# Epoch 46/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4972 - root_mean_squared_error: 0.2668 - val_loss: 0.6105 - val_root_mean_squared_error: 0.3493
# Epoch 47/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.5012 - root_mean_squared_error: 0.2703 - val_loss: 0.6099 - val_root_mean_squared_error: 0.3490
# Epoch 48/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4959 - root_mean_squared_error: 0.2657 - val_loss: 0.6093 - val_root_mean_squared_error: 0.3486
# Epoch 49/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4941 - root_mean_squared_error: 0.2650 - val_loss: 0.6085 - val_root_mean_squared_error: 0.3482
# Epoch 50/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4909 - root_mean_squared_error: 0.2623 - val_loss: 0.6080 - val_root_mean_squared_error: 0.3480
# Epoch 51/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4901 - root_mean_squared_error: 0.2626 - val_loss: 0.6084 - val_root_mean_squared_error: 0.3484
# Epoch 52/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4941 - root_mean_squared_error: 0.2647 - val_loss: 0.6088 - val_root_mean_squared_error: 0.3487
# Epoch 53/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4860 - root_mean_squared_error: 0.2597 - val_loss: 0.6088 - val_root_mean_squared_error: 0.3488
# Epoch 54/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4899 - root_mean_squared_error: 0.2618 - val_loss: 0.6091 - val_root_mean_squared_error: 0.3488
# Epoch 55/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4874 - root_mean_squared_error: 0.2608 - val_loss: 0.6077 - val_root_mean_squared_error: 0.3480
# Epoch 56/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4849 - root_mean_squared_error: 0.2576 - val_loss: 0.6069 - val_root_mean_squared_error: 0.3476
# Epoch 57/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4819 - root_mean_squared_error: 0.2565 - val_loss: 0.6065 - val_root_mean_squared_error: 0.3473
# Epoch 58/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4833 - root_mean_squared_error: 0.2574 - val_loss: 0.6054 - val_root_mean_squared_error: 0.3466
# Epoch 59/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4772 - root_mean_squared_error: 0.2529 - val_loss: 0.6045 - val_root_mean_squared_error: 0.3461
# Epoch 60/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4775 - root_mean_squared_error: 0.2523 - val_loss: 0.6044 - val_root_mean_squared_error: 0.3461
# Epoch 61/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4796 - root_mean_squared_error: 0.2546 - val_loss: 0.6052 - val_root_mean_squared_error: 0.3466
# Epoch 62/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4797 - root_mean_squared_error: 0.2544 - val_loss: 0.6018 - val_root_mean_squared_error: 0.3446
# Epoch 63/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4738 - root_mean_squared_error: 0.2506 - val_loss: 0.6013 - val_root_mean_squared_error: 0.3442
# Epoch 64/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4767 - root_mean_squared_error: 0.2536 - val_loss: 0.6009 - val_root_mean_squared_error: 0.3439
# Epoch 65/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4815 - root_mean_squared_error: 0.2570 - val_loss: 0.5995 - val_root_mean_squared_error: 0.3431
# Epoch 66/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4757 - root_mean_squared_error: 0.2529 - val_loss: 0.5993 - val_root_mean_squared_error: 0.3430
# Epoch 67/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4738 - root_mean_squared_error: 0.2508 - val_loss: 0.6005 - val_root_mean_squared_error: 0.3438
# Epoch 68/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4708 - root_mean_squared_error: 0.2488 - val_loss: 0.5990 - val_root_mean_squared_error: 0.3428
# Epoch 69/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4699 - root_mean_squared_error: 0.2481 - val_loss: 0.5985 - val_root_mean_squared_error: 0.3425
# Epoch 70/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4727 - root_mean_squared_error: 0.2512 - val_loss: 0.5989 - val_root_mean_squared_error: 0.3427
# Epoch 71/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4676 - root_mean_squared_error: 0.2472 - val_loss: 0.5989 - val_root_mean_squared_error: 0.3428
# Epoch 72/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4713 - root_mean_squared_error: 0.2492 - val_loss: 0.5972 - val_root_mean_squared_error: 0.3418
# Epoch 73/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4645 - root_mean_squared_error: 0.2443 - val_loss: 0.5955 - val_root_mean_squared_error: 0.3405
# Epoch 74/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4677 - root_mean_squared_error: 0.2468 - val_loss: 0.5955 - val_root_mean_squared_error: 0.3405
# Epoch 75/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4669 - root_mean_squared_error: 0.2466 - val_loss: 0.5953 - val_root_mean_squared_error: 0.3405
# Epoch 76/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4680 - root_mean_squared_error: 0.2476 - val_loss: 0.5949 - val_root_mean_squared_error: 0.3405
# Epoch 77/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4629 - root_mean_squared_error: 0.2442 - val_loss: 0.5946 - val_root_mean_squared_error: 0.3401
# Epoch 78/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4604 - root_mean_squared_error: 0.2419 - val_loss: 0.5965 - val_root_mean_squared_error: 0.3413
# Epoch 79/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4621 - root_mean_squared_error: 0.2437 - val_loss: 0.5956 - val_root_mean_squared_error: 0.3407
# Epoch 80/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4633 - root_mean_squared_error: 0.2445 - val_loss: 0.5951 - val_root_mean_squared_error: 0.3404
# Epoch 81/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4608 - root_mean_squared_error: 0.2429 - val_loss: 0.5936 - val_root_mean_squared_error: 0.3395
# Epoch 82/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4592 - root_mean_squared_error: 0.2422 - val_loss: 0.5935 - val_root_mean_squared_error: 0.3394
# Epoch 83/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4576 - root_mean_squared_error: 0.2410 - val_loss: 0.5935 - val_root_mean_squared_error: 0.3392
# Epoch 84/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4622 - root_mean_squared_error: 0.2429 - val_loss: 0.5954 - val_root_mean_squared_error: 0.3403
# Epoch 85/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4595 - root_mean_squared_error: 0.2415 - val_loss: 0.5965 - val_root_mean_squared_error: 0.3411
# Epoch 86/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4591 - root_mean_squared_error: 0.2414 - val_loss: 0.5966 - val_root_mean_squared_error: 0.3412
# Epoch 87/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4540 - root_mean_squared_error: 0.2383 - val_loss: 0.5976 - val_root_mean_squared_error: 0.3419
# Epoch 88/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4543 - root_mean_squared_error: 0.2390 - val_loss: 0.5983 - val_root_mean_squared_error: 0.3423
# Epoch 89/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4571 - root_mean_squared_error: 0.2413 - val_loss: 0.5964 - val_root_mean_squared_error: 0.3413
# Epoch 90/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4480 - root_mean_squared_error: 0.2330 - val_loss: 0.5962 - val_root_mean_squared_error: 0.3413
# Epoch 91/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4562 - root_mean_squared_error: 0.2400 - val_loss: 0.5963 - val_root_mean_squared_error: 0.3412
# Epoch 92/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4493 - root_mean_squared_error: 0.2348 - val_loss: 0.5952 - val_root_mean_squared_error: 0.3406
# Epoch 93/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4556 - root_mean_squared_error: 0.2406 - val_loss: 0.5947 - val_root_mean_squared_error: 0.3402
# Epoch 94/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4563 - root_mean_squared_error: 0.2398 - val_loss: 0.5958 - val_root_mean_squared_error: 0.3409
# Epoch 95/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4583 - root_mean_squared_error: 0.2425 - val_loss: 0.5961 - val_root_mean_squared_error: 0.3411
# Epoch 96/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4557 - root_mean_squared_error: 0.2399 - val_loss: 0.5969 - val_root_mean_squared_error: 0.3416
# Epoch 97/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4506 - root_mean_squared_error: 0.2357 - val_loss: 0.5963 - val_root_mean_squared_error: 0.3414
# Epoch 98/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4492 - root_mean_squared_error: 0.2362 - val_loss: 0.5951 - val_root_mean_squared_error: 0.3407
# Epoch 99/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4493 - root_mean_squared_error: 0.2364 - val_loss: 0.5956 - val_root_mean_squared_error: 0.3409
# Epoch 100/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.4496 - root_mean_squared_error: 0.2357 - val_loss: 0.5960 - val_root_mean_squared_error: 0.3410

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model_metrics')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
resto_new
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-07c1b31675e7> in <module>()
# ----> 1 resto_new
#
# NameError: name 'resto_new' is not defined

# %%
resto_df = resto_new
df = pd.read_csv('rating_final.csv')
 
# Mengambil sample user
user_id = df.userID.sample(1).iloc[0]
resto_visited_by_user = df[df.userID == user_id]
 
# Operator bitwise (~), bisa diketahui di sini https://docs.python.org/3/reference/expressions.html 
resto_not_visited = resto_df[~resto_df['id'].isin(resto_visited_by_user.placeID.values)]['id'] 
resto_not_visited = list(
    set(resto_not_visited)
    .intersection(set(resto_to_resto_encoded.keys()))
)
 
resto_not_visited = [[resto_to_resto_encoded.get(x)] for x in resto_not_visited]
user_encoder = user_to_user_encoded.get(user_id)
user_resto_array = np.hstack(
    ([[user_encoder]] * len(resto_not_visited), resto_not_visited)
)

# %%
ratings = model.predict(user_resto_array).flatten()
 
top_ratings_indices = ratings.argsort()[-10:][::-1]
recommended_resto_ids = [
    resto_encoded_to_resto.get(resto_not_visited[x][0]) for x in top_ratings_indices
]
 
print('Showing recommendations for users: {}'.format(user_id))
print('===' * 9)
print('Resto with high ratings from user')
print('----' * 8)
 
top_resto_user = (
    resto_visited_by_user.sort_values(
        by = 'rating',
        ascending=False
    )
    .head(5)
    .placeID.values
)
 
resto_df_rows = resto_df[resto_df['id'].isin(top_resto_user)]
for row in resto_df_rows.itertuples():
    print(row.resto_name, ':', row.cuisine)
 
print('----' * 8)
print('Top 10 resto recommendation')
print('----' * 8)
 
recommended_resto = resto_df[resto_df['id'].isin(recommended_resto_ids)]
for row in recommended_resto.itertuples():
    print(row.resto_name, ':', row.cuisine)
